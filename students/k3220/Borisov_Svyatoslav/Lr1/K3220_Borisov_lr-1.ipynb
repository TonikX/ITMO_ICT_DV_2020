# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
db = pd.read_csv(r'C:\dataus.csv',encoding='cp866')

# %%
dblogan = db[db['channel_title'] == 'Logan Paul Vlogs']

# %%
dblogan.plot('trending_date','dislikes',figsize = [15,5])

# %%
dblogan.plot('trending_date','comment_count',figsize = [15,5])

# %%
dbapple = db[db['channel_title'] == 'iJustine']

# %%
dbapple.plot('trending_date','views',figsize = [16,5])

# %%
dbapple2 = dbapple[dbapple["views"] > 1000000]

# %%
dbapple2.head(10)
# Out:
#           video_id trending_date                             title  \
# 1154   gHZ1Qz0KiKM      17.19.11             2 Weeks with iPhone X
# 1379   gHZ1Qz0KiKM      17.20.11             2 Weeks with iPhone X
# 18124  L9FBI1kOEHo      18.14.02                 HomePod Unboxing!
# 18364  L9FBI1kOEHo      18.15.02                 HomePod Unboxing!
# 34858  4HX6R88QZB0      18.15.05  Original 2007 iPhone Unboxing!!!
# 35068  4HX6R88QZB0      18.16.05  Original 2007 iPhone Unboxing!!!
# 35276  4HX6R88QZB0      18.17.05  Original 2007 iPhone Unboxing!!!
# 35486  4HX6R88QZB0      18.18.05  Original 2007 iPhone Unboxing!!!
# 35687  4HX6R88QZB0      18.19.05  Original 2007 iPhone Unboxing!!!
# 35890  4HX6R88QZB0      18.20.05  Original 2007 iPhone Unboxing!!!
#
#       channel_title  category_id              publish_time  \
# 1154       iJustine           28  2017-11-13T19:07:23.000Z
# 1379       iJustine           28  2017-11-13T19:07:23.000Z
# ...

# %%
dbbeast = db[db['channel_title'] == 'Dude Perfect']

# %%
dbbeast.plot('trending_date', 'likes', figsize = [16,5])

# %%
dbbeast.plot('trending_date', 'dislikes', figsize = [16,5])

# %%
dbbeast.sort_values("dislikes", ascending = False)
# Out:
#           video_id trending_date                                     title  \
# 36297  FepIkIILumA      18.22.05        Fortnite with Ninja | Dude Perfect
# 36094  FepIkIILumA      18.21.05        Fortnite with Ninja | Dude Perfect
# 35872  FepIkIILumA      18.20.05        Fortnite with Ninja | Dude Perfect
# 35670  FepIkIILumA      18.19.05        Fortnite with Ninja | Dude Perfect
# 23644  MuPL-PSMX0Q      18.14.03  World's Longest LEGO Walk | Dude Perfect
# ...            ...           ...                                       ...
# 9661   9oyKePWRi8Y      18.01.01               Best of 2017 | Dude Perfect
# 9457   9oyKePWRi8Y      17.31.12               Best of 2017 | Dude Perfect
# 9238   9oyKePWRi8Y      17.30.12               Best of 2017 | Dude Perfect
# 9022   9oyKePWRi8Y      17.29.12               Best of 2017 | Dude Perfect
# 8814   9oyKePWRi8Y      17.28.12               Best of 2017 | Dude Perfect
#
#       channel_title  category_id              publish_time  \
# ...
